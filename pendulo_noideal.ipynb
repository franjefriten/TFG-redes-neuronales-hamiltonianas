# %% [markdown]
# #### FRANCISCO JESÚS FRÍAS TENZA
# #### TRABAJO DE FINAL DE GRADO, GRADO EN FÍSICA, UNIVERSIDAD DE ALICANTE, FACULTAD DE CIENCIAS
# #### REDES NEURONALES HAMILTONIANAS
#
# ## PÉNDULO NO IDEAL

# %% [markdown]
# #### IMPORTAR LIBRERÍAS

# %%
# Trabajo de Final de Grado, Grado en Física, 2022-2023
# Redes Neuronales Hamiltonianas
# Péndulo real no ideal
# Francisco Jesús Frías Tenza

import warnings

import matplotlib.pyplot as plt
import matplotlib as mlp
import matplotlib.cm as cm
import matplotlib.colors as colors

from scipy.integrate import solve_ivp

import autograd
import autograd.numpy as np

import argparse
import os, sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow import keras
import tensorflow as tf

import pandas as pd

# %%
global system_config
system_config = {"m": 1,
                 "l": 1,
                 "g": 10,
                 "kappa": 0.5}

TASA_DE_APRENDIZAJE = 0.005       
CICLOS = 2500               
DIM_OCULTA = 200

# %% [markdown]
# #### Definición del Hamiltoniano
# Definimos el hamiltoniano del sistema y la función de Raylegth para la pérdida de energía

# %%
def IdealPendulumHam(coords: np.ndarray) -> float:
    """
    Esta función es el hamiltoniano analítico del sistema de un péndulo no ideal

    INPUT
    -----
    coords
        array con q, p para cada cuerpo. Las filas son las coordenadas (qx, qy, qz, px, py, pz) y las columnas los cuerpos.
    system_config
        diccionario con los parámetros del sistema, masa, constante elástica, etc.
    """
    q, p = np.split(coords, 2)
    m, l, g = system_config["m"], system_config['l'], system_config['g']
    return  m*g*l * (1 - np.cos(q)) +  p**2 / (2*m*l**2)

# %%
def PendulumRayleighFunc(coords: np.ndarray) -> float:
    """
    Esta función es la función de Rayleght para el péndulo simple

    INPUT
    -----
    coords
        array con q, p para cada cuerpo. Las filas son las coordenadas (qx, qy, qz, px, py, pz) y las columnas los cuerpos.
    system_config
        diccionario con los parámetros del sistema, masa, constante elástica, etc.
    """
    q, p = np.split(coords,2)
    m, l, g = system_config["m"], system_config['l'], system_config['g']
    return 0.5 * system_config['kappa'] * ( p**2 / (m * l**2) ) # l**2 qdot**2 derivada coord generalizada = p**2 / m**2*l**2

# %%
def TFPendulumRayleighFunc(coords: tf.Tensor) -> float:
    """
    Esta función es la función de Rayleght para el péndulo simple con comptabilidad con TensorFlow

    INPUT
    -----
    coords
        Tensor con q, p para cada cuerpo. Las filas son las coordenadas (qx, qy, qz, px, py, pz) y las columnas los cuerpos.
    system_config
        diccionario con los parámetros del sistema, masa, constante elástica, etc.
    """
    q, p = coords[0,:], coords[1,:]
    #print(coords)
    #print(q, p)
    m, l, g = system_config["m"], system_config['l'], system_config['g']
    #print(0.5 * system_config['kappa'] * ( p**2 / (m**2 * l**2) ))
    return 0.5 * system_config['kappa'] * ( p**2 / (m**2 * l**2) ) # l**2 qdot**2 derivada coord generalizada = p**2 / m**2*l**2

# %% [markdown]
# #### Gradiente simplético y gradiente simplético no ideal
# El gradiente simplético no ideal tiene en cuenta la pérdida de energía a través de la función de Rayleght

# %%
def SympGrad(t, coords):
    """
    gradiente simpléctico
    """
    dcoords = autograd.grad(IdealPendulumHam)(coords)
    S = np.array([[0,  1],
                  [-1, 0]]) @ dcoords    
    return S

def NonIdealSympGrad(t, coords):
    """
    gradiente simpléctico no ideal
    """   
    m, l, g = system_config["m"], system_config['l'], system_config['g']
    dcoords = autograd.grad(IdealPendulumHam)(coords)
    # Annadimos la funcion de Raylegth
    S = np.array([[0,  1],
                  [-1, 0]]) @ dcoords - np.array([0, autograd.grad(PendulumRayleighFunc)(coords)[1] * m * l**2]).T
    return S

# %% [markdown]
# #### Cómputo de la trayectoria y generación del set de datos

# %%
def trayectoria(t_final: float, t_inicio: float, dt: float, y0: np.ndarray, ruido) -> np.ndarray:
    r"""
    Tomando las ecuaciones de Hamilton $\frac{dq}{dt} = \frac{dH}{dp}$ y $\frac{dq}{dt} = \frac{dH}{dp}$
    vamos a interpretarlas como un sistema de ecuaciones diferenciales del tipo dy/dt = f(x,y,t) sobre las 
    que hay que integrar numericamente. Emplearemos el metodo Runge-Kutta de orden 4 para obtener q(t+dt), p(d+dt).
    h es salto temporal, que va a ser el mismo para las coordenadas.
    """
    N = int((t_final - t_inicio) / dt)
    t_space = np.linspace(t_inicio, t_final, N)

    solu = solve_ivp(fun=NonIdealSympGrad, t_span=(t_inicio, t_final), y0=y0, t_eval=t_space, atol=1e-5, rtol=1e-5)
    y = solu.y
    q, p = y[0,:], y[1,:]
    coords = y.copy()
    dcoords_dt = np.empty((2, N))
    for i in range(0, N):
        dcoords_dt[:,i] = NonIdealSympGrad(t=t_space[i], coords=coords[:,i])
    dqdt, dpdt = dcoords_dt[0,:], dcoords_dt[1,:]

    ## Annadimos ruido a los datos
    q += np.random.randn(*q.shape)*ruido
    p += np.random.randn(*p.shape)*ruido

    return q, p, dqdt, dpdt, t_space, dt

# %%
def generate_dataset(semilla=1, muestras=50, ruido=0.1, **kwargs):

    # muestreamos inpus y outputs aleatorios
    np.random.seed(semilla)
    q_data, p_data, dqdt_data, dpdt_data = [], [], [], []
    t_final = np.random.uniform(20, 50)
    for _ in range(muestras):
        y0 = np.random.rand(2, 1) * 20 # generar semillas iniciales aleatorias
        #print(t_final)
        q, p, dq, dp, t_space, dt = trayectoria(t_final=t_final, t_inicio=0, dt = 0.1, y0=y0.T[0], ruido=ruido)
        #print(q, p, dq, dp)
        #print(q.shape if _ == 1 else pass)
        q_data.append(q); p_data.append(p)
        dqdt_data.append(dq); dpdt_data.append(dp)
    
    split_data = {
        "dq": np.concatenate(dqdt_data, axis=-1), # Y set
        "dp": np.concatenate(dpdt_data, axis=-1),
        "q": np.concatenate(q_data, axis=-1),  # X set
        "p": np.concatenate(p_data, axis=-1),
    }

    df = pd.DataFrame.from_dict(split_data, orient='columns')

    return df

# %% [markdown]
# #### Funciones para plots

# %%
def get_field(xmin=-6, xmax=6, ymin=-6, ymax=6, gridsize=20):
    y_grid, x_grid = np.meshgrid(np.linspace(xmin, xmax, gridsize), np.linspace(ymin, ymax, gridsize))
    dxdt = np.empty_like(y_grid)
    dydt = np.empty_like(x_grid)
    for j, y in enumerate(np.linspace(ymin, ymax, gridsize)):
        for i, x in enumerate(np.linspace(xmin, xmax, gridsize)):
            aux = NonIdealSympGrad(t=None, coords=np.array([x,y]).T)
            dxdt[i,j], dydt[i,j] = aux[0], aux[1] 
    return x_grid, y_grid, dxdt, dydt

def plot_figures_compare(q, p, dqdt, dpdt, t_space, dt):

    x_grid, y_grid, dxdt, dydt = get_field(gridsize=15)

    N = len(q)
    color = mlp.colormaps['Reds']
    color_aux = mlp.colormaps['Blues']
    color_ranges = np.sqrt(p[::10]**2/2 + q[::10]**2/2)

    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
    fig.set_size_inches(w=11, h=11)
    fig.tight_layout(pad=6.5)
    ax1_twinx = ax1.twinx()
    ax3_twinx = ax3.twinx()

    ax1.plot(t_space, q, "r-", label=r"$q(t)$")
    ax1.set_ylabel('Posición (m)', )
    ax1.xaxis.label.set_color('black')
    ax1.yaxis.label.set_color('red')
    ax1.tick_params(colors='red', axis='y')

    ax1_twinx.plot(t_space, p, "b-", label=r"$p(t)$")  
    ax1.set_xlabel('Tiempo (s)')
    ax1_twinx.set_ylabel('Velocidad (m/s)')
    ax1_twinx.xaxis.label.set_color('black')
    ax1_twinx.yaxis.label.set_color('blue')
    ax1_twinx.tick_params(colors='blue', axis='y')
    ax1.legend(bbox_to_anchor=(0.75, 1.2))
    ax1_twinx.legend(bbox_to_anchor=(0.95, 1.2))

    #ax2.scatter(q[::10], p[::10], c=np.sqrt(p[::10]**2 + q[::10]**2), cmap=color, label="Espacio de Fase")
    ax2.quiver(x_grid, y_grid, dxdt, dydt, cmap='bwr', label="Espacio de fases")
    ax2.set_xlabel("q")
    ax2.set_ylabel("p")
    ax2.legend(bbox_to_anchor=(0.95, 1.15))

    #ax3.plot(t_space, np.cos(t_space), color="blue", linestyle="dashed", label=r"$q(t)$ solucion analítica")
    #ax3_twinx.plot(t_space, -np.sin(t_space), color="cyan", linestyle="dashed", label=r"$p(t)$ solucion analítica")
    ax3.plot(t_space, q, "r-", label=r"$q(t)$ solución numérica")
    ax3_twinx.plot(t_space, p, color="orange", label=r"$p(t)$ solución numérica")  
    ax3.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
            ncol=3, fancybox=True, shadow=False)    
    ax3_twinx.legend(loc='lower center', bbox_to_anchor=(0.5, -0.3),
          ncol=3, fancybox=True, shadow=False)
    ax3.set_ylabel('Posición (m)', )
    #ax3.tick_params(colors='red', axis='y')
    ax3.set_xlabel('Tiempo (s)')
    ax3_twinx.set_ylabel('Velocidad (m/s)')
    #ax3_twinx.tick_params(colors='blue', axis='y')

    ax4.scatter(q[::10], p[::10], s=5, c=color_ranges, cmap=color, 
                norm=colors.CenteredNorm(vcenter=color_ranges.max()/2,
                                         halfrange=color_ranges.max()/2, clip=True),
                #vmin=0, vmax=color_ranges.max(),
                label="Resultado numérico")
    #ax4.scatter(np.cos(t_space[::10]), -np.sin(t_space[::10]), s=1.5, c=color_ranges, cmap=color_aux, 
    #            norm=colors.CenteredNorm(vcenter=color_ranges.max()/2,
    #                                     halfrange=color_ranges.max()/2, clip=True),
                #vmin=0, vmax=color_ranges.max(),
    #            label="Resultado analítico")
    #ax4.quiver(x_grid, y_grid, dxdt, dydt, cmap='PRGn', color=(.5,.5,.5), alpha=0.5)
    ax4.set_xlabel("q")
    ax4.legend(loc='upper right')
    ax4.set_ylabel("p")
    ax4.set_xlim((-2, 2))
    ax4.set_ylim((-4, 4))
    
    
    #ax4.scatter(q[::2], p[::2], c=np.sqrt(p**2 + q**2), label="Espacio de Fase")
    
    fig.savefig(r".\img\dis_pen_{}_{}".format(int(q[0]), int(p[0])))

# %% [markdown]
# #### Definición de los modelos
#
# Red Neuronal Hamiltoniana HNN
#
# Cargamos los pesos del modelo ideal y los usamos para el modelo no ideal

# %%
class HNN(tf.Module):
  
  def __init__(self, dim_entrada, dim_oculta, name=None):
    super().__init__(name=name)
    self.dim_entrada = dim_entrada
    self.dim_oculta = dim_oculta
    self.capa1 = tf.keras.layers.InputLayer(input_shape=self.dim_entrada) # Input layer
    self.capa2 = tf.keras.layers.Dense(units=self.dim_oculta, activation='tanh')
    self.capa3 = tf.keras.layers.Dense(units=self.dim_oculta, activation='tanh') 
    # Si se busca crear más capas, ha de copiarse y pegar el siguiente código
    # self.capa_n = tf.keras.layers.Dense(units=dim_oculta, activation='tanh') # donde "_n" es u numero natural
    self.capa4 = tf.keras.layers.Dense(1) # Output layer
    O = np.zeros((dim_entrada//2, dim_entrada//2))
    I = np.identity(dim_entrada//2)
    R_90 = np.concatenate([np.concatenate((O, I), axis=1), np.concatenate((-I, O), axis=1)], axis=0)
    self.R_90 = tf.constant(R_90, dtype='double')

  @tf.Module.with_name_scope
  def __call__(self, x):
    y = self.capa1(x)
    y = self.capa2(y)
    #y = self.capa3(y)
    y = self.capa4(y)
    return y
  
  def compute_symplectic_gradient(self, x):
    with tf.GradientTape() as tape:
      y = self.capa1(x)
      y = self.capa2(y)
      #y = self.capa3(y)
      y = self.capa4(y)
    y = tape.gradient(y, x)
    y = y @ np.linalg.inv(self.R_90)
    return y
  
  def entrenar_HNN(self, data, tasa_de_aprendizaje = TASA_DE_APRENDIZAJE, ciclos = CICLOS):
    warnings.filterwarnings('ignore')
    loss_array = np.zeros(ciclos+1)
    # Tomamos el algoritmo Adam para optimización
    adam_aldoritmo = tf.keras.optimizers.Adam(learning_rate=tasa_de_aprendizaje)
    # Declaramos la función de coste
    funcion_coste_L2 = tf.keras.losses.MeanSquaredError()
    ciclo = 0
    while ciclo <= ciclos:
        with tf.GradientTape() as tape_coste: # Este es el gradiente de la función de coste
            tape_coste.watch(self.trainable_variables) # Esto nos permite 'vigilar' las variables de TensorFlow
            y_train_keys = [key for key in data.columns if 'd' in key]
            y_test_keys = [key for key in data.columns if 'd' not in key]
            y_pred = self.compute_symplectic_gradient(tf.Variable(tf.stack(data[y_test_keys]))) # SympGrad del Hamiltoniano
            y_real = tf.Variable(tf.stack(data[y_train_keys]))
            loss = funcion_coste_L2(y_pred=y_pred, y_true=y_real) # Evaluación de la función de coste
        # Creamos el gradiente
        gradiente_funcion_coste_L2 = tape_coste.gradient(loss, self.trainable_variables)
        # El siguiente paso es opcional, usamos esto para agilizar el entrenamiento
        adam_aldoritmo.apply_gradients(zip(gradiente_funcion_coste_L2, self.trainable_variables))
        print(ciclo, loss)
        loss_array[ciclo] = loss
        ciclo += 1
    warnings.resetwarnings()

    return loss_array

# %% [markdown]
# #### Entrenamiento de la red neuronal

# %%
def integrar_HNN(modelo, **kwargs):
    return solve_ivp(fun=lambda t, x: modelo.compute_symplectic_gradient(tf.Variable(tf.reshape(x, (1, modelo.dim_entrada)), dtype='double')), **kwargs)

# %%
hnn_modelo = HNN(dim_entrada=2, dim_oculta=DIM_OCULTA)
loss = hnn_modelo.entrenar_HNN(data=generate_dataset(), tasa_de_aprendizaje=TASA_DE_APRENDIZAJE, ciclos=CICLOS)
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 0 tf.Tensor(8.082154911731347, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 1 tf.Tensor(8.048317120986507, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2 tf.Tensor(8.016409512830153, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 3 tf.Tensor(7.986049148704744, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 4 tf.Tensor(7.957113434372472, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 5 tf.Tensor(7.929574869128291, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 6 tf.Tensor(7.903321198309504, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 7 tf.Tensor(7.878224418462438, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 8 tf.Tensor(7.8541049573144575, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 9 tf.Tensor(7.830605071126189, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 10 tf.Tensor(7.807072100608724, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 11 tf.Tensor(7.782840308666842, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 12 tf.Tensor(7.757763306178177, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 13 tf.Tensor(7.731938185456741, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 14 tf.Tensor(7.705534556290101, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 15 tf.Tensor(7.678751242978835, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 16 tf.Tensor(7.651739425527978, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 17 tf.Tensor(7.624534140793126, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 18 tf.Tensor(7.597088101887372, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 19 tf.Tensor(7.569162719996882, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 20 tf.Tensor(7.540784704762281, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 21 tf.Tensor(7.512350804585275, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 22 tf.Tensor(7.484045479733429, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 23 tf.Tensor(7.455845630219873, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 24 tf.Tensor(7.427720582976103, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 25 tf.Tensor(7.399684223361082, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 26 tf.Tensor(7.371852859159459, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 27 tf.Tensor(7.3442299703461265, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 28 tf.Tensor(7.316769000041847, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 29 tf.Tensor(7.289621651909491, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 30 tf.Tensor(7.262961062389796, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 31 tf.Tensor(7.236855624314743, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 32 tf.Tensor(7.211362972211957, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 33 tf.Tensor(7.186470840591444, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 34 tf.Tensor(7.162260967072762, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 35 tf.Tensor(7.138880621949885, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 36 tf.Tensor(7.1163582970549255, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 37 tf.Tensor(7.09462513902266, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 38 tf.Tensor(7.073631747761695, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 39 tf.Tensor(7.053341334545378, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 40 tf.Tensor(7.033735168341336, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 41 tf.Tensor(7.014751551185231, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 42 tf.Tensor(6.996285123226269, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 43 tf.Tensor(6.978220782421458, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 44 tf.Tensor(6.960489234130074, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 45 tf.Tensor(6.943111033808633, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 46 tf.Tensor(6.92611282082668, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 47 tf.Tensor(6.909299316999741, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 48 tf.Tensor(6.892496256758647, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 49 tf.Tensor(6.87576939361398, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 50 tf.Tensor(6.859222638112949, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 51 tf.Tensor(6.842901576800259, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 52 tf.Tensor(6.826840666360005, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 53 tf.Tensor(6.811038394781465, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 54 tf.Tensor(6.795875570795687, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 55 tf.Tensor(6.781303218625393, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 56 tf.Tensor(6.76552693922878, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 57 tf.Tensor(6.748477251848795, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 58 tf.Tensor(6.733620603861513, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 59 tf.Tensor(6.7196085242544, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 60 tf.Tensor(6.703504089638254, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 61 tf.Tensor(6.687749819379151, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 62 tf.Tensor(6.67403041215419, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 63 tf.Tensor(6.65989731620479, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 64 tf.Tensor(6.644457020219188, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 65 tf.Tensor(6.629836072041249, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 66 tf.Tensor(6.616649810727426, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 67 tf.Tensor(6.603373479318894, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 68 tf.Tensor(6.588960283041088, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 69 tf.Tensor(6.574509775490099, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 70 tf.Tensor(6.561377586477588, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 71 tf.Tensor(6.548985925027844, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 72 tf.Tensor(6.536090501751747, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 73 tf.Tensor(6.522580295699858, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 74 tf.Tensor(6.509540517803659, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 75 tf.Tensor(6.497325688159564, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 76 tf.Tensor(6.4853016955887215, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 77 tf.Tensor(6.472994353769093, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 78 tf.Tensor(6.460184056460527, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 79 tf.Tensor(6.447422493717416, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 80 tf.Tensor(6.435121746694369, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 81 tf.Tensor(6.423348668101452, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 82 tf.Tensor(6.412029870305389, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 83 tf.Tensor(6.401139884047499, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 84 tf.Tensor(6.390844490941752, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 85 tf.Tensor(6.38026130523429, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 86 tf.Tensor(6.368183091010474, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 87 tf.Tensor(6.354877328554007, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 88 tf.Tensor(6.343335183873102, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 89 tf.Tensor(6.333885429047934, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 90 tf.Tensor(6.324315551282196, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 91 tf.Tensor(6.313044381395192, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 92 tf.Tensor(6.300736750947936, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 93 tf.Tensor(6.289932242263315, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 94 tf.Tensor(6.280782963651974, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 95 tf.Tensor(6.271549437943377, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 96 tf.Tensor(6.261076973452566, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 97 tf.Tensor(6.249691101698795, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 98 tf.Tensor(6.23915396821342, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 99 tf.Tensor(6.2299817421259025, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 100 tf.Tensor(6.221370432254056, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 101 tf.Tensor(6.212462697272676, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 102 tf.Tensor(6.202574325331909, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 103 tf.Tensor(6.192242675703592, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 104 tf.Tensor(6.182322045425437, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 105 tf.Tensor(6.173293363617248, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 106 tf.Tensor(6.164946953756274, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 107 tf.Tensor(6.156879431427424, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 108 tf.Tensor(6.1488381360480275, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 109 tf.Tensor(6.140183836254142, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 110 tf.Tensor(6.130860392253554, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 111 tf.Tensor(6.12107766643069, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 112 tf.Tensor(6.111822341866216, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 113 tf.Tensor(6.1034675806632945, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# ...
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2463 tf.Tensor(3.920966135188285, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2464 tf.Tensor(3.919545614087753, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2465 tf.Tensor(3.9181451858835503, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2466 tf.Tensor(3.9168001980734686, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2467 tf.Tensor(3.9154772129146713, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2468 tf.Tensor(3.914135440229911, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2469 tf.Tensor(3.9127673795611346, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2470 tf.Tensor(3.9113807902130864, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2471 tf.Tensor(3.9099775285584744, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2472 tf.Tensor(3.9085695149916577, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2473 tf.Tensor(3.907172468431649, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2474 tf.Tensor(3.9057839939244943, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2475 tf.Tensor(3.904395034960061, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2476 tf.Tensor(3.9030073929896125, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2477 tf.Tensor(3.901614780950371, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2478 tf.Tensor(3.9002106557651333, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2479 tf.Tensor(3.8987924985383904, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2480 tf.Tensor(3.8973714539931263, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2481 tf.Tensor(3.8959510569028626, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2482 tf.Tensor(3.894531917162315, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2483 tf.Tensor(3.8931078004264927, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2484 tf.Tensor(3.8916859479676074, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2485 tf.Tensor(3.8902716975967113, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2486 tf.Tensor(3.88887784209188, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2487 tf.Tensor(3.887518345802119, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2488 tf.Tensor(3.8862018397379363, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2489 tf.Tensor(3.8849245609005467, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2490 tf.Tensor(3.8835575175741366, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2491 tf.Tensor(3.8820523166532905, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2492 tf.Tensor(3.8803594844691007, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2493 tf.Tensor(3.8787711994155822, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2494 tf.Tensor(3.8774361509241237, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2495 tf.Tensor(3.876295409825617, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2496 tf.Tensor(3.8751153720940743, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2497 tf.Tensor(3.873837242683191, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2498 tf.Tensor(3.8725335874308726, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2499 tf.Tensor(3.871435779691335, shape=(), dtype=float64)
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_5/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2500 tf.Tensor(3.8704738101062146, shape=(), dtype=float64)

# %% [markdown]
# #### Demostración

# %%
plot_figures_compare(*trayectoria(t_final=10, t_inicio=0, dt=0.01, y0=np.array([1,0]), ruido=0))

# %% [markdown]
# #### Análisis

# %%
t_span = [0,20]
t_puntos = 2000
t_eval = np.linspace(t_span[0], t_span[1], t_puntos)
atol = 1e-9; rtol = 1e-9
y0 = np.array([1, 0])
kwargs = {'y0': y0, 't_span': t_span, 't_eval': t_eval, 'rtol': rtol, 'atol': atol}
hnn_trayectoria = integrar_HNN(hnn_modelo, **kwargs)

# %%
def T(p, system_config):
    m = system_config['m']
    l = system_config['l']
    return p**2 / (2*m*l**2)

def U(x, system_config):
    g = system_config['g']
    l = system_config['l']
    m = system_config['m']
    return m * g * l * (1 - np.cos(x))

color = mlp.colormaps['Blues']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(8, 8)
fig.tight_layout(pad=1.1, h_pad=3, w_pad=3)

x, y, dx, dy, t, dt = trayectoria(t_final=20, t_inicio=0, dt=0.01, y0=np.array([1, 0]), ruido=0)

ax1.scatter(x[::10], y[::10], c=np.sqrt(x[::10]**2 + y[::10]**2), cmap=color, label='data')
ax1.set_xlabel("q", fontsize=10)
ax1.set_ylabel("p", fontsize=10)
ax1.set_title("Dinámica")
ax1.legend(loc='upper right')
ax1.grid()

ax2.plot(hnn_trayectoria['y'].T[:,0], hnn_trayectoria['y'].T[:,1], color='b', linewidth=2)    
ax2.set_xlabel("q", fontsize=10)
ax2.set_ylabel("p", fontsize=10)
ax2.set_title("HNN")
ax2.grid()

U_energias = U(hnn_trayectoria['y'].T[:,0])
T_energias = T(hnn_trayectoria['y'].T[:,1])
E_energias = T_energias + U_energias

ax3.plot(t, T_energias, color='b', linewidth=2, label="T")
ax3.plot(t, U_energias, color='r', linewidth=2, label="U")
ax3.plot(t, E_energias, color='k', linewidth=2, label="E")    
ax3.set_xlabel("Tiempo (s)", fontsize=10)
ax3.set_ylabel("Energía (J)", rotation=90, fontsize=10)
ax3.set_title("HNN Energía", pad=10)
ax3.legend()
ax3.grid()

ax4.plot(np.arange(len(loss)), loss, linewidth=2, label="Función de coste")    
ax4.set_xlabel("Iteraciones", fontsize=10)
ax4.set_ylabel(r"$\Lambda$", rotation=90, fontsize=10)
ax4.set_title(r"Optimización de $\Lambda$")
ax4.legend()
ax4.grid()

plt.savefig(r".\img\dis_hnn_pred_{}_{}.png".format(int(x[0]), int(y[0])))
